# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries

import matplotlib.pyplot as plt
import math
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1

# %%
plt.plot(x, x, label='x')
plt.plot(x, y, label='x,y')

plt.xlabel('x label')
plt.ylabel('y label')

plt.title("Plot(x,y)")
plt.legend()
plt.show()

# %%
plt.plot(x, x, label='x')
plt.plot(x, z, label='x,z')

plt.xlabel('x label')
plt.ylabel('z label')

plt.title("Plot(x,z)")
plt.legend()
plt.show()

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, [ax1, ax2] = plt.subplots(1,2) 

ax1.plot(x,y) 
ax1.set_title('Plot(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('Plot(x,z)')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show() # used to show the plots

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
fig, [ax1, ax2] = plt.subplots(1,2,figsize=(10,10)) 

ax1.plot(x,y) 
ax1.set_title('Plot(x,y)')   
ax1.set_xlabel('x label')     
ax1.set_ylabel('y label')   

ax2.plot(x,z)
ax2.set_title('Plot(x,z)')
ax2.set_xlabel('x label')
ax2.set_ylabel('z label')

plt.show()

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
from math import e
plt.plot(x,x**x)
plt.plot(x, e**x)

# %%
fig2, m2 = plt.subplots(nrows=1,ncols=2,figsize=[6,4])
fig2.suptitle('Sub plots')

m2[0].plot(x,x**x)
m2[1].plot(x,e**x)

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %%
fig2, m2 = plt.subplots(nrows=1,ncols=2,figsize=[6,4])
fig2.suptitle('Sub plots')

m2[0].plot(x,x**x)  
m2[0].set_title('y = squareroot of x')   
m2[0].set_xlabel('x label')     
m2[0].set_ylabel('y label')   

m2[1].plot(x,e**x)  
m2[1].set_title('y = e exponential x')
m2[1].set_xlabel('x label')
m2[1].set_ylabel('y label')

plt.show()

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
fitbit=pd.read_csv(r'/Users/nadimsaad/Desktop/IRONHACK/Module 2/Week 4/Day 16/Fitbit2.csv')

# %%
fitbit.head(10)
# Out:
#          Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0  2015-05-08            1934    905      0.65       0              1.355
# 1  2015-05-09            3631  18925     14.11       4            611.000
# 2  2015-05-10            3204  14228     10.57       1            602.000
# 3  2015-05-11            2673   6756      5.02       8            749.000
# 4  2015-05-12            2495    502      3.73       1            876.000
# 5  2015-05-13             276    779      5.79      15            726.000
# 6  2015-05-14            2687   5614      4.17       2            782.000
# 7  2015-05-15            2793   8169      6.07      14            801.000
# 8  2015-05-16            4061  19971     14.84      18            532.000
# 9  2015-05-17            3349    852      6.33      12            606.000
#
#    Minutes Lightly Active  Minutes Fairly Active  Minutes Very Active  \
# 0                      46                      0                    0
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# fitbit_mean = fitbit[["Steps", "Months_encoded"]].groupby(["Steps"]).agg("median")
fitbit_median = fitbit[["Months_encoded","Steps"]].groupby(["Months_encoded"]).agg("median")

fitbit_median.plot.bar()
plt.savefig("Months_encoded.jpg")

# %%
# MEDIAN STEPS BY WORK_OR_WEEKEND
fitbit_mean = fitbit[["Work_or_Weekend","Steps"]].groupby(["Work_or_Weekend"]).agg("median")
fitbit_mean.plot.barh()
plt.savefig("Work_or_Weekend.jpg")

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
col=["Minutes Lightly Active", "Minutes Very Active", "Minutes Sedentary"]
for i in col:
    x= fitbit.plot(kind='scatter', x='Steps', y=i)
    print(x)
# Out:
# AxesSubplot(0.125,0.1;0.775x0.8)
# AxesSubplot(0.125,0.1;0.775x0.8)
# AxesSubplot(0.125,0.1;0.775x0.8)

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
titanic=pd.read_csv(r'/Users/nadimsaad/Desktop/IRONHACK/Module 2/Week 4/Day 16/titanic.csv')

# %%
titanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
# 5            6       0.0       3
# 6            7       0.0       1
# 7            8       0.0       3
# 8            9       1.0       3
# 9           10       1.0       2
#
#                                                 Name  Gender  Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male   22      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                             Heikkinen, Miss. Laina  female   26      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                           Allen, Mr. William Henry    male   35      0
# 5                                   Moran, Mr. James    male   23      0
# 6                            McCarthy, Mr. Timothy J    male   54      0
# ...

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
PassengerID
Survived
Pclass
Age
SibSp
Parch
Fare

# %%
# CATEGORICAL VARIABLES
Name
Gender
Ticket
Cabin
Embarked

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
import matplotlib.style

plt.style.use('classic')
mpl.rcParams['figure.figsize'] = [12.0, 6.0]

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
titanic['Age']=titanic['Age'].astype(int)
distribution_of_Age= titanic[['Age','PassengerId']].groupby(['Age']).agg('count')
distribution_of_Age.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
titanic['Age'].plot(kind='hist', bins=[10,20,50])
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# #### How does the bin size affect your plot?

# %%
# bin size defines the start and end points

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
# Generate histogram/distribution plot
sns.displot(titanic['Age'])
plt.show()

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - Seaborn

sns.displot(titanic, x="Gender")

# %%
# Method 2 - matplotlib

titanic.groupby('Gender').size().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='None'>

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
# titanic.groupby('Pclass').size().plot(kind='pie', autopct='%.2f')
titanic["Pclass"].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <AxesSubplot:ylabel='Pclass'>

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
titanic["Age"].describe()
# Out:
# count    1309.000000
# mean       29.747135
# std        13.469166
# min         0.000000
# 25%        22.000000
# 50%        28.000000
# 75%        37.000000
# max        80.000000
# Name: Age, dtype: float64

# %%
sns.distplot(titanic.Age,bins=40,hist=True, kde=False)
plt.title('Distribution of age')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
# This plot shows the age concentration (avg age was 28) of the Titanic passengers

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
# your code here

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib

fig = plt.figure(figsize=(10,5)) 

ax1 = fig.add_subplot(121)
sns.distplot(titanic.Fare)
plt.title('Distribution of fare price')
plt.ylabel('Density')

axe2=fig.add_subplot(122)
sns.distplot(titanic.Age,bins=40,hist=True, kde=False)
plt.title('Distribution of age')
plt.ylabel('Count')
# Out:
# /Users/nadimsaad/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'Count')

# %%
# Method 2 - seaborn
fig = plt.figure(figsize=(10,5)) 

ax1 = fig.add_subplot(121)
ax1=sns.countplot(x="Age", data=titanic)
plt.title("Distribution of Age")

fig.add_subplot(122)
ax2 = sns.countplot(x="Fare", data=titanic)
plt.title('Distributrion of Fare')
# Out:
# Text(0.5, 1.0, 'Distributrion of Fare')

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
titanic.corr()
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.038354  0.025248 -0.055224  0.008942
# Survived       -0.005007  1.000000 -0.338481 -0.064080 -0.035322  0.081629
# Pclass         -0.038354 -0.338481  1.000000 -0.429681  0.060832  0.018322
# Age             0.025248 -0.064080 -0.429681  1.000000 -0.260134 -0.143979
# SibSp          -0.055224 -0.035322  0.060832 -0.260134  1.000000  0.373587
# Parch           0.008942  0.081629  0.018322 -0.143979  0.373587  1.000000
# Fare            0.031128  0.257307 -0.558683  0.173464  0.160349  0.221635
#
#                  Fare
# PassengerId  0.031128
# Survived     0.257307
# Pclass      -0.558683
# Age          0.173464
# SibSp        0.160349
# Parch        0.221635
# Fare         1.000000

# %%
sns.heatmap(titanic.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### What are the most correlated features?

# %%
We observe significant correlation (>0.5) among Pclass and Survived
also between Age and Pclass 
Between Pclass and Fare

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
x1 = fig.add_subplot(122)
sns.barplot(x='Age', y='Pclass',hue='Pclass',data=titanic)
plt.title('Age and class')
# Out:
# <ipython-input-95-00315ba953bb>:1: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   x1 = fig.add_subplot(122)
# Text(0.5, 1.0, 'Age and class')

# %%
sns.boxplot(x='Pclass', y='Age', data=titanic).set_title('Comparison of Passenger Ages by Class')
# Out:
# Text(0.5, 1.0, 'Comparison of Passenger Ages by Class')

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(titanic, col='Gender')
g.map(plt.hist, 'Age', bins=20)
